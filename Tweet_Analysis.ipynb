# %% [markdown]
# # Tweeter Sentiment Analysis
#
#     Name - Aniket Madhukar Rindhe
#     Roll No. - TEB21
#     Subject - DSBDA
#     Project Name - Tweeter Sentiment Analysis

# %%
import pandas as pd

# %%
pip install seaborn
# Out:
# ...
#
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data_science.csv")

# %%
df
# Out:
#                          id      conversation_id               created_at  \
# 0       1406400408545804288  1406400396264943616  2021-06-20 05:26:01 IST
# 1       1406390341176016897  1406390341176016897  2021-06-20 04:46:01 IST
# 2       1406386311481774083  1406386311481774083  2021-06-20 04:30:00 IST
# 3       1406383545153638402  1406383545153638402  2021-06-20 04:19:01 IST
# 4       1406358632648818689  1406358632648818689  2021-06-20 02:40:01 IST
# ...                     ...                  ...                      ...
# 241381           7516204805           7516204805  2010-01-08 17:36:43 IST
# 241382           7445162404           7445162404  2010-01-06 21:41:51 IST
# 241383           7423411210           7423332793  2010-01-06 07:01:47 IST
# 241384           7376226272           7376226272  2010-01-05 00:54:11 IST
# 241385           7333962778           7333962778  2010-01-03 20:33:45 IST
#
#               date      time  timezone              user_id         username  \
# ...

# %%
df.head(8)
# Out:
#                     id      conversation_id               created_at  \
# 0  1406400408545804288  1406400396264943616  2021-06-20 05:26:01 IST
# 1  1406390341176016897  1406390341176016897  2021-06-20 04:46:01 IST
# 2  1406386311481774083  1406386311481774083  2021-06-20 04:30:00 IST
# 3  1406383545153638402  1406383545153638402  2021-06-20 04:19:01 IST
# 4  1406358632648818689  1406358632648818689  2021-06-20 02:40:01 IST
# 5  1406350577756524555  1406350577756524555  2021-06-20 02:08:01 IST
# 6  1406344023254634499  1405541746675572749  2021-06-20 01:41:58 IST
# 7  1406341015963799553  1406341015963799553  2021-06-20 01:30:01 IST
#
#          date      time  timezone              user_id         username  \
# 0  2021-06-20  05:26:01       530  1113747629282930688  ballouxfrancois
# 1  2021-06-20  04:46:01       530   788898706586275840     tdatascience
# 2  2021-06-20  04:30:00       530             19402238      sciencenews
# ...

# %%
df['reply_to']
# Out:
# 0         []
# 1         []
# 2         []
# 3         []
# 4         []
#           ..
# 241381    []
# 241382    []
# 241383    []
# 241384    []
# 241385    []
# Name: reply_to, Length: 241386, dtype: object

# %%
# Task 
#     - Text Preprocessing
#     - Sentimate Analysis
#     - Keyword Extraction 
#     - Entity Extraction

# %%
df.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
df['tweet'].head()
# Out:
# 0    What can be done?  - Never blindly trust an ab...
# 1    "We need a paradigm shift from model-centric t...
# 2    Using high-resolution satellite data and compu...
# 3    .@Stephenson_Data shares four steps that will ...
# 4    "Curricula is inherently brittle in a world wh...
# Name: tweet, dtype: object

# %%
df.dtypes
# Out:
# id                   int64
# conversation_id      int64
# created_at          object
# date                object
# time                object
# timezone             int64
# user_id              int64
# username            object
# name                object
# place               object
# tweet               object
# language            object
# mentions            object
# urls                object
# photos              object
# replies_count        int64
# retweets_count       int64
# likes_count          int64
# hashtags            object
# cashtags            object
# link                object
# retweet               bool
# quote_url           object
# video                int64
# thumbnail           object
# near               float64
# geo                float64
# source             float64
# user_rt_id         float64
# user_rt            float64
# retweet_id         float64
# reply_to            object
# retweet_date       float64
# translate          float64
# ...

# %%
df['source'].unique
# Out:
# <bound method Series.unique of 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 241381   NaN
# 241382   NaN
# 241383   NaN
# 241384   NaN
# 241385   NaN
# Name: source, Length: 241386, dtype: float64>

# %%
df['source'].value_counts()
# Out:
# Series([], Name: source, dtype: int64)

# %%
#Text Analysis Of Tweets

# %%
# !pip install neattext

# %%
import neattext.functions as nfx

# %%
dir(nfx)
# Out:
# ['BTC_ADDRESS_REGEX',
#  'CURRENCY_REGEX',
#  'CURRENCY_SYMB_REGEX',
#  'Counter',
#  'DATE_REGEX',
#  'EMAIL_REGEX',
#  'EMOJI_REGEX',
#  'HASTAG_REGEX',
#  'MASTERCard_REGEX',
#  'MD5_SHA_REGEX',
#  'MOST_COMMON_PUNCT_REGEX',
#  'NUMBERS_REGEX',
#  'PHONE_REGEX',
#  'PoBOX_REGEX',
#  'SPECIAL_CHARACTERS_REGEX',
#  'STOPWORDS',
#  'STOPWORDS_de',
#  'STOPWORDS_en',
#  'STOPWORDS_es',
#  'STOPWORDS_fr',
#  'STOPWORDS_ru',
#  'STOPWORDS_yo',
#  'STREET_ADDRESS_REGEX',
#  'TextFrame',
#  'URL_PATTERN',
#  'USER_HANDLES_REGEX',
#  'VISACard_REGEX',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__generate_text',
#  '__loader__',
#  '__name__',
#  '__numbers_dict',
#  '__package__',
#  '__spec__',
#  '_lex_richness_herdan',
#  '_lex_richness_maas_ttr',
#  'clean_text',
#  'defaultdict',
#  'digit2words',
#  'extract_btc_address',
#  'extract_currencies',
#  'extract_currency_symbols',
#  'extract_dates',
#  'extract_emails',
#  'extract_emojis',
# ...

# %%
df['tweet']
# Out:
# 0         What can be done?  - Never blindly trust an ab...
# 1         "We need a paradigm shift from model-centric t...
# 2         Using high-resolution satellite data and compu...
# 3         .@Stephenson_Data shares four steps that will ...
# 4         "Curricula is inherently brittle in a world wh...
#                                 ...
# 241381    Cda jobs data, Dec: employment rose in health,...
# 241382    RT @filiber: Have a Computer Science backgroun...
# 241383    @pop17 Heck with science. I've got empirical d...
# 241384    All in the....data RT @noahWG Dr. Petra provid...
# 241385    “The world of retail will always be a mix of a...
# Name: tweet, Length: 241386, dtype: object

# %%
df['tweet'].iloc[6]
# Out:
# '@LinkLabsInc @IoTchannel Wow! Wonderful!! Congratulations and thank you. (And in my Maryland neighborhood too!)😎    —————  @IoTchannel @IoTCommunity #IoT #IoTPL #IIoT #IoTCommunity #AI #Edge #EdgeAI #5G #DigitalTransformation #Industry40 #BigData #DataScience #EdgeComputing #Observability  https://t.co/2zrcINZCf3'

# %%
# we have to remove noise from the givent data
# 1. remove mentions/userhandles
# 2. remove hashtags
# 3. urls
# 4. emojis
# 5. special char

# %%
df.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1406400408545804288  1406400396264943616  2021-06-20 05:26:01 IST
# 1  1406390341176016897  1406390341176016897  2021-06-20 04:46:01 IST
# 2  1406386311481774083  1406386311481774083  2021-06-20 04:30:00 IST
# 3  1406383545153638402  1406383545153638402  2021-06-20 04:19:01 IST
# 4  1406358632648818689  1406358632648818689  2021-06-20 02:40:01 IST
#
#          date      time  timezone              user_id         username  \
# 0  2021-06-20  05:26:01       530  1113747629282930688  ballouxfrancois
# 1  2021-06-20  04:46:01       530   788898706586275840     tdatascience
# 2  2021-06-20  04:30:00       530             19402238      sciencenews
# 3  2021-06-20  04:19:01       530   788898706586275840     tdatascience
# 4  2021-06-20  02:40:01       530   788898706586275840     tdatascience
#
#                     name place  ... geo source user_rt_id user_rt retweet_id  \
# ...

# %%
df['tweet'].apply(nfx.extract_hashtags)
# Out:
# 0         []
# 1         []
# 2         []
# 3         []
# 4         []
#           ..
# 241381    []
# 241382    []
# 241383    []
# 241384    []
# 241385    []
# Name: tweet, Length: 241386, dtype: object

# %%
df['tweet'].apply(nfx.extract_hashtags).head(10)
# Out:
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# 5                                                   []
# 6    [#IoT, #IoTPL, #IIoT, #IoTCommunity, #AI, #Edg...
# 7    [#HPEDiscover, #Edge, #Cloud, #IoT, #IIoT, #Io...
# 8    [#ModelOps, #MLOps?, #AI, #EnterpriseAI, #Mach...
# 9    [#AI, #BigData, #DataScience, #DAIFE, #DataMin...
# Name: tweet, dtype: object

# %%
df['extracted_hashtags'] = df['tweet'].apply(nfx.extract_hashtags).head(10)

# %%
df[['extracted_hashtags','hashtags']].head(10)
# Out:
#                                   extracted_hashtags  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6  [#IoT, #IoTPL, #IIoT, #IoTCommunity, #AI, #Edg...
# 7  [#HPEDiscover, #Edge, #Cloud, #IoT, #IIoT, #Io...
# 8  [#ModelOps, #MLOps?, #AI, #EnterpriseAI, #Mach...
# 9  [#AI, #BigData, #DataScience, #DAIFE, #DataMin...
#
#                                             hashtags
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# ...

# %%
df['clean_tweet'] = df['tweet'].apply(nfx.remove_hashtags)

# %%
df['clean_tweet'].iloc[6]
# Out:
# '@LinkLabsInc @IoTchannel Wow! Wonderful!! Congratulations and thank you. (And in my Maryland neighborhood too!)😎    —————  @IoTchannel @IoTCommunity                              https://t.co/2zrcINZCf3'

# %%
df[['tweet', 'clean_tweet']]
# Out:
#                                                     tweet  \
# 0       What can be done?  - Never blindly trust an ab...
# 1       "We need a paradigm shift from model-centric t...
# 2       Using high-resolution satellite data and compu...
# 3       .@Stephenson_Data shares four steps that will ...
# 4       "Curricula is inherently brittle in a world wh...
# ...                                                   ...
# 241381  Cda jobs data, Dec: employment rose in health,...
# 241382  RT @filiber: Have a Computer Science backgroun...
# 241383  @pop17 Heck with science. I've got empirical d...
# 241384  All in the....data RT @noahWG Dr. Petra provid...
# 241385  “The world of retail will always be a mix of a...
#
#                                               clean_tweet
# 0       What can be done?  - Never blindly trust an ab...
# 1       "We need a paradigm shift from model-centric t...
# 2       Using high-resolution satellite data and compu...
# ...

# %%
df['clean_tweet'] = df['clean_tweet'].apply(lambda x : nfx.remove_userhandles(x))

# %%
df[['tweet','clean_tweet']]
# Out:
#                                                     tweet  \
# 0       What can be done?  - Never blindly trust an ab...
# 1       "We need a paradigm shift from model-centric t...
# 2       Using high-resolution satellite data and compu...
# 3       .@Stephenson_Data shares four steps that will ...
# 4       "Curricula is inherently brittle in a world wh...
# ...                                                   ...
# 241381  Cda jobs data, Dec: employment rose in health,...
# 241382  RT @filiber: Have a Computer Science backgroun...
# 241383  @pop17 Heck with science. I've got empirical d...
# 241384  All in the....data RT @noahWG Dr. Petra provid...
# 241385  “The world of retail will always be a mix of a...
#
#                                               clean_tweet
# 0       What can be done?  - Never blindly trust an ab...
# 1       "We need a paradigm shift from model-centric t...
# 2       Using high-resolution satellite data and compu...
# ...

# %%
df['clean_tweet'] = df['clean_tweet'].apply(nfx.remove_multiple_spaces)

# %%
df['clean_tweet'] = df['clean_tweet'].apply(nfx.remove_urls)

# %%
df['clean_tweet'].iloc[6]
# Out:
# ' Wow! Wonderful!! Congratulations and thank you. (And in my Maryland neighborhood too!)😎 ————— '

# %%
df['clean_tweet'] = df['clean_tweet'].apply(nfx.remove_puncts)

# %%
df[['tweet','clean_tweet']]
# Out:
#                                                     tweet  \
# 0       What can be done?  - Never blindly trust an ab...
# 1       "We need a paradigm shift from model-centric t...
# 2       Using high-resolution satellite data and compu...
# 3       .@Stephenson_Data shares four steps that will ...
# 4       "Curricula is inherently brittle in a world wh...
# ...                                                   ...
# 241381  Cda jobs data, Dec: employment rose in health,...
# 241382  RT @filiber: Have a Computer Science backgroun...
# 241383  @pop17 Heck with science. I've got empirical d...
# 241384  All in the....data RT @noahWG Dr. Petra provid...
# 241385  “The world of retail will always be a mix of a...
#
#                                               clean_tweet
# 0       What can be done  Never blindly trust an abstr...
# 1       We need a paradigm shift from modelcentric to ...
# 2       Using highresolution satellite data and comput...
# ...

# %% [markdown]
# # Sentiment Analysis

# %%
# !pip install textblob

# %%
from textblob import TextBlob

# %%
def get_sentiment(text):
    blob = TextBlob(text)
    sentiment_polarity = blob.sentiment.polarity
    sentiment_subjectivity = blob.sentiment.subjectivity
    if sentiment_polarity > 0: 
        sentiment_label = 'Positive'
    elif sentiment_polarity < 0:
        sentiment_label = 'Negative'
    else : 
        sentiment_label = 'Neutral'
    result = {'polarity': sentiment_polarity,
              'Subjectivity' : sentiment_subjectivity,
              'sentiment' : sentiment_label}
    return result

def plot_sentiment_graph(sentiment_data):
    sentiments = [data['sentiment'] for data in sentiment_data]
    plt.figure(figsize=(8,6))
    plt.hist(sentiments, bins=3, color='skyblue', edgecolor='black')
    plt.title('Sentiment Distribution')
    plt.xlabel('Sentiment')
    plt.ylabel('Count')
    plt.show()

# %%
df['clean_tweet'].iloc[6]
# Out:
# ' Wow Wonderful Congratulations and thank you (And in my Maryland neighborhood too)😎 ————— '

# %%
ex1 = df['clean_tweet']

# %%
sentiment_data = [get_sentiment(text) for text in ex1]
plot_sentiment_graph(sentiment_data)
